# %%
#START_HERE
#Notebook serves as tutorial.

# %%
#START
#CELL 1
# numpy and pandas for data manipulation
import numpy as np
import pandas as pd
import s3fs

# sklearn preprocessing for dealing with categorical variables
from sklearn.preprocessing import LabelEncoder

# File system manangement
import os

#Garbage Collector
import gc 

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# matplotlib and seaborn for plotting
#import seaborn as sns    NOTE: Will have to install seaborn later
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix,roc_auc_score, roc_curve, auc 
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

#To read in files
fs = s3fs.S3FileSystem(anon=False)

# %%
#CELL 2
#Read in application_train.csv 
with fs.open('group12credits/application_train.csv') as f:
    train_df = pd.read_csv(f)

# %%
#CELL 3
#Get the ids in application train
valid_IDs=train_df['SK_ID_CURR'].copy()
valid_IDs.sort()

#Get the ids and target values from application_train 
bareBones=train_df[['SK_ID_CURR','TARGET']].copy()

#Delete train_df and call gc.collect() to avoid memory errors 
#import gc 
#del train_df 
#gc.collect()

# %%
#CELL 4
#Read in the other csv file (previous_application.csv)
with fs.open('group12credits/previous_application.csv') as f:
    prevApps_all = pd.read_csv(f)
    
#Filter out the rows in the other csv file that are not part of application_train so there is less memory used 
#Sort values by the IDs for easier processing 
filteredApps=prevApps_all.loc[prevApps_all['SK_ID_CURR'].isin(valid_IDs)].sort_values(by=['SK_ID_CURR'])

#delete data frames we are not using anymore avoid memory leaks, call garbage collector 
#import gc
del prevApps_all, valid_IDs
gc.collect()
# Out:
# 579

# %%
#CELL 5
#Merge or inner join bareBones and filtered Apps together 
prevApps=filteredApps.merge(bareBones,on='SK_ID_CURR',how='inner')

# %%
#CELL 6

#Set csv_df to merged file to perform pre-processing needed 
#Note: This will be used to check how each of the columns correlates to the Target variable. 
#The columns with the highest correlations will be added in one at a time to check if this improves our ROC AUC Curve/Classifier

csv_df=prevApps

#Avoid memory leaks 
del prevApps
gc.collect()
# Out:
# 31

# %%
#CELL 7
#Check number of columns before pre-processing:
len(csv_df.columns)
# Out:
# 124

# %%
#CELL 8
# Create a label encoder object to perform label encoding on objects with 2 or fewer unique catergories.(i.e.sex@birth 1=female, 0=male)

le = LabelEncoder()
le_count = 0

# Iterate through the columns
for col in csv_df:
    if csv_df[col].dtype == 'object':
        # If 2 or fewer unique categories
        if len(list(csv_df[col].unique())) <= 2:
            # Train on the training data
            le.fit(csv_df[col])
            # Transform both training and testing data  NOTE: Removed testing data
            csv_df[col] = le.transform(csv_df[col])
            
            # Keep track of how many columns were label encoded
            le_count += 1
            
print('%d columns were label encoded.' % le_count)
# Out:
# 3 columns were label encoded.

# %%
#CELL 9
# one-hot encoding of categorical variables
csv_df = pd.get_dummies(csv_df)

# %%
#CELL 10

#Replace all spaces with underscores
csv_df.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# Find correlations with the target and sort (takes a minute to compile)
correlations = csv_df.corr()['TARGET'].sort_values()

# %%
#CELL 11

#Find how each column correlates to target 

import re
def interpretCorrelations(c):
    for line in c:
        title = line.split(' ')[0]
        status = ""
        try:
            num = abs(float(list(filter(None, line.split(' ')))[1]))
            if num <= .19:
                status = "very weak"
            elif num <= .39:
                status = "weak"
            elif num <= .59:
                status = "moderate"
            elif num <= .79:
                status = "strong"
            elif num <= 1:
                status = "very strong"
            #print(title + "\t" + str(num) + "\t" + status)
            print("Title: {0:30} Correlation: {1:5}\tStatus: {2:50}".format(title, num, status))
        except:
            print("An error occurred parsing the correlation coefficient")
            pass
        
    
# Display correlations
interpretCorrelations(correlations.to_string().splitlines())
# Out:
# Title: CODE_REJECT_REASON_XAP         Correlation: 0.052015	Status: very weak
# Title: NAME_CONTRACT_STATUS_Approved  Correlation: 0.049161	Status: very weak
# Title: DAYS_FIRST_DRAWING             Correlation: 0.031154	Status: very weak
# Title: NAME_PORTFOLIO_POS             Correlation: 0.030791	Status: very weak
# Title: NAME_CONTRACT_TYPE_Consumer_loans Correlation: 0.02994	Status: very weak
# Title: HOUR_APPR_PROCESS_START        Correlation: 0.027809	Status: very weak
# Title: NAME_YIELD_GROUP_low_normal    Correlation: 0.026615	Status: very weak
# Title: RATE_DOWN_PAYMENT              Correlation: 0.026111	Status: very weak
# Title: NAME_PAYMENT_TYPE_Cash_through_the_bank Correlation: 0.026079	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Consumer_electronics Correlation: 0.022125	Status: very weak
# Title: PRODUCT_COMBINATION_Cash_X-Sell:_low Correlation: 0.021469	Status: very weak
# Title: PRODUCT_COMBINATION_POS_industry_with_interest Correlation: 0.020967	Status: very weak
# Title: NAME_YIELD_GROUP_low_action    Correlation: 0.019016	Status: very weak
# Title: NAME_GOODS_CATEGORY_Furniture  Correlation: 0.018184	Status: very weak
# Title: CHANNEL_TYPE_Stone             Correlation: 0.017659	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Furniture Correlation: 0.017103	Status: very weak
# Title: AMT_DOWN_PAYMENT               Correlation: 0.016918	Status: very weak
# Title: PRODUCT_COMBINATION_POS_household_without_interest Correlation: 0.016543	Status: very weak
# Title: NAME_TYPE_SUITE_Family         Correlation: 0.016141	Status: very weak
# Title: NAME_GOODS_CATEGORY_Consumer_Electronics Correlation: 0.015984	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_XAP     Correlation: 0.014932	Status: very weak
# Title: AMT_ANNUITY                    Correlation: 0.014922	Status: very weak
# Title: PRODUCT_COMBINATION_POS_household_with_interest Correlation: 0.014302	Status: very weak
# Title: NAME_PRODUCT_TYPE_XNA          Correlation: 0.014145	Status: very weak
# Title: NAME_CLIENT_TYPE_Refreshed     Correlation: 0.013955	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Clothing  Correlation: 0.012452	Status: very weak
# Title: NAME_GOODS_CATEGORY_Clothing_and_Accessories Correlation: 0.012451	Status: very weak
# Title: PRODUCT_COMBINATION_POS_industry_without_interest Correlation: 0.012419	Status: very weak
# Title: NAME_PRODUCT_TYPE_x-sell       Correlation: 0.012355	Status: very weak
# Title: NAME_YIELD_GROUP_middle        Correlation: 0.011894	Status: very weak
# Title: NAME_TYPE_SUITE_Children       Correlation: 0.011431	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Construction Correlation: 0.010014	Status: very weak
# Title: CHANNEL_TYPE_Regional_/_Local  Correlation: 0.009877	Status: very weak
# Title: CHANNEL_TYPE_Country-wide      Correlation: 0.00928	Status: very weak
# Title: NAME_GOODS_CATEGORY_Audio/Video Correlation: 0.008965	Status: very weak
# Title: PRODUCT_COMBINATION_Cash_X-Sell:_middle Correlation: 0.008876	Status: very weak
# Title: NAME_TYPE_SUITE_Unaccompanied  Correlation: 0.008687	Status: very weak
# Title: NAME_GOODS_CATEGORY_Construction_Materials Correlation: 0.007434	Status: very weak
# Title: WEEKDAY_APPR_PROCESS_START_SUNDAY Correlation: 0.007083	Status: very weak
# Title: DAYS_FIRST_DUE                 Correlation: 0.006651	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Industry  Correlation: 0.005585	Status: very weak
# Title: AMT_APPLICATION                Correlation: 0.005583	Status: very weak
# Title: FLAG_LAST_APPL_PER_CONTRACT    Correlation: 0.005539	Status: very weak
# Title: NAME_GOODS_CATEGORY_Medical_Supplies Correlation: 0.005178	Status: very weak
# Title: NAME_GOODS_CATEGORY_Computers  Correlation: 0.005104	Status: very weak
# Title: CHANNEL_TYPE_Channel_of_corporate_sales Correlation: 0.00502	Status: very weak
# Title: NAME_GOODS_CATEGORY_Tourism    Correlation: 0.004819	Status: very weak
# Title: NAME_GOODS_CATEGORY_Photo_/_Cinema_Equipment Correlation: 0.004559	Status: very weak
# Title: WEEKDAY_APPR_PROCESS_START_SATURDAY Correlation: 0.004506	Status: very weak
# Title: NAME_GOODS_CATEGORY_Other      Correlation: 0.004228	Status: very weak
# Title: NAME_GOODS_CATEGORY_Homewares  Correlation: 0.003968	Status: very weak
# Title: PRODUCT_COMBINATION_POS_mobile_without_interest Correlation: 0.00328	Status: very weak
# Title: NAME_TYPE_SUITE_Spouse,_partner Correlation: 0.003159	Status: very weak
# Title: NFLAG_LAST_APPL_IN_DAY         Correlation: 0.002887	Status: very weak
# Title: NAME_GOODS_CATEGORY_Gardening  Correlation: 0.002794	Status: very weak
# Title: NAME_GOODS_CATEGORY_Medicine   Correlation: 0.002711	Status: very weak
# Title: SELLERPLACE_AREA               Correlation: 0.002539	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Tourism   Correlation: 0.002532	Status: very weak
# Title: AMT_CREDIT                     Correlation: 0.00235	Status: very weak
# Title: NAME_SELLER_INDUSTRY_MLM_partners Correlation: 0.00224	Status: very weak
# Title: PRODUCT_COMBINATION_POS_other_with_interest Correlation: 0.002237	Status: very weak
# Title: NAME_GOODS_CATEGORY_Sport_and_Leisure Correlation: 0.002129	Status: very weak
# Title: CHANNEL_TYPE_Car_dealer        Correlation: 0.002099	Status: very weak
# Title: PRODUCT_COMBINATION_POS_others_without_interest Correlation: 0.001983	Status: very weak
# Title: CODE_REJECT_REASON_SYSTEM      Correlation: 0.001865	Status: very weak
# Title: CODE_REJECT_REASON_CLIENT      Correlation: 0.001836	Status: very weak
# Title: NAME_CONTRACT_STATUS_Unused_offer Correlation: 0.001836	Status: very weak
# Title: NAME_PORTFOLIO_Cars            Correlation: 0.001825	Status: very weak
# Title: NAME_GOODS_CATEGORY_Fitness    Correlation: 0.001711	Status: very weak
# Title: RATE_INTEREST_PRIMARY          Correlation: 0.00147	Status: very weak
# Title: SK_ID_CURR                     Correlation: 0.001246	Status: very weak
# Title: NAME_PAYMENT_TYPE_Non-cash_from_your_account Correlation: 0.001122	Status: very weak
# Title: NAME_GOODS_CATEGORY_Education  Correlation: 0.000857	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Buying_a_garage Correlation: 0.000844	Status: very weak
# Title: NAME_GOODS_CATEGORY_Additional_Service Correlation: 0.000697	Status: very weak
# Title: NAME_TYPE_SUITE_Other_B        Correlation: 0.000603	Status: very weak
# Title: NAME_PAYMENT_TYPE_Cashless_from_the_account_of_the_employer Correlation: 0.000531	Status: very weak
# Title: NAME_GOODS_CATEGORY_Office_Appliances Correlation: 0.000525	Status: very weak
# Title: NAME_GOODS_CATEGORY_Animals    Correlation: 0.000259	Status: very weak
# Title: NAME_GOODS_CATEGORY_Direct_Sales Correlation: 0.000257	Status: very weak
# Title: NAME_GOODS_CATEGORY_Weapon     Correlation: 0.000232	Status: very weak
# Title: NAME_GOODS_CATEGORY_Mobile     Correlation: 0.000117	Status: very weak
# Title: NAME_TYPE_SUITE_Other_A        Correlation: 0.000141	Status: very weak
# Title: AMT_GOODS_PRICE                Correlation: 0.000254	Status: very weak
# Title: NAME_TYPE_SUITE_Group_of_people Correlation: 0.000275	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Jewelry   Correlation: 0.000302	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Buying_a_new_car Correlation: 0.000333	Status: very weak
# Title: NAME_GOODS_CATEGORY_Insurance  Correlation: 0.000385	Status: very weak
# Title: WEEKDAY_APPR_PROCESS_START_WEDNESDAY Correlation: 0.000638	Status: very weak
# Title: NFLAG_INSURED_ON_APPROVAL      Correlation: 0.000653	Status: very weak
# Title: NAME_GOODS_CATEGORY_Jewelry    Correlation: 0.000831	Status: very weak
# Title: NAME_GOODS_CATEGORY_Auto_Accessories Correlation: 0.000986	Status: very weak
# Title: CODE_REJECT_REASON_VERIF       Correlation: 0.000999	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Money_for_a_third_person Correlation: 0.001253	Status: very weak
# Title: WEEKDAY_APPR_PROCESS_START_FRIDAY Correlation: 0.001426	Status: very weak
# Title: NAME_CLIENT_TYPE_XNA           Correlation: 0.001482	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Refusal_to_name_the_goal Correlation: 0.001555	Status: very weak
# Title: WEEKDAY_APPR_PROCESS_START_TUESDAY Correlation: 0.001689	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_XNA     Correlation: 0.001807	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Journey Correlation: 0.001929	Status: very weak
# Title: SK_ID_PREV                     Correlation: 0.002009	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Education Correlation: 0.002011	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Buying_a_holiday_home_/_land Correlation: 0.002075	Status: very weak
# Title: PRODUCT_COMBINATION_POS_mobile_with_interest Correlation: 0.002182	Status: very weak
# Title: NAME_GOODS_CATEGORY_Vehicles   Correlation: 0.002241	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Hobby   Correlation: 0.002276	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Business_development Correlation: 0.002357	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Everyday_expenses Correlation: 0.002537	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Wedding_/_gift_/_holiday Correlation: 0.002608	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Buying_a_home Correlation: 0.002636	Status: very weak
# Title: CODE_REJECT_REASON_XNA         Correlation: 0.002856	Status: very weak
# Title: WEEKDAY_APPR_PROCESS_START_MONDAY Correlation: 0.00309	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Furniture Correlation: 0.003246	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Auto_technology Correlation: 0.003276	Status: very weak
# Title: WEEKDAY_APPR_PROCESS_START_THURSDAY Correlation: 0.003494	Status: very weak
# Title: NAME_CLIENT_TYPE_Repeater      Correlation: 0.003505	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Purchase_of_electronic_equipment Correlation: 0.00354	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Gasification_/_water_supply Correlation: 0.004395	Status: very weak
# Title: NAME_PORTFOLIO_Cash            Correlation: 0.00487	Status: very weak
# Title: PRODUCT_COMBINATION_Card_X-Sell Correlation: 0.005141	Status: very weak
# Title: NAME_CLIENT_TYPE_New           Correlation: 0.005725	Status: very weak
# Title: NAME_CONTRACT_TYPE_XNA         Correlation: 0.006072	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Medicine Correlation: 0.006163	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Buying_a_used_car Correlation: 0.006284	Status: very weak
# Title: CODE_REJECT_REASON_SCO         Correlation: 0.007342	Status: very weak
# Title: PRODUCT_COMBINATION_Cash_Street:_low Correlation: 0.007384	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Building_a_house_or_an_annex Correlation: 0.007489	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Car_repairs Correlation: 0.007648	Status: very weak
# Title: NAME_CONTRACT_STATUS_Canceled  Correlation: 0.008739	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Payments_on_other_loans Correlation: 0.008742	Status: very weak
# Title: NAME_SELLER_INDUSTRY_Connectivity Correlation: 0.008837	Status: very weak
# Title: CHANNEL_TYPE_Credit_and_cash_offices Correlation: 0.010869	Status: very weak
# Title: CHANNEL_TYPE_Contact_center    Correlation: 0.011971	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Other   Correlation: 0.013236	Status: very weak
# Title: PRODUCT_COMBINATION_Cash       Correlation: 0.014069	Status: very weak
# Title: NAME_CONTRACT_TYPE_Cash_loans  Correlation: 0.014932	Status: very weak
# Title: PRODUCT_COMBINATION_Cash_Street:_middle Correlation: 0.015485	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Urgent_needs Correlation: 0.016065	Status: very weak
# Title: NAME_PORTFOLIO_Cards           Correlation: 0.016466	Status: very weak
# Title: NAME_YIELD_GROUP_high          Correlation: 0.016636	Status: very weak
# Title: DAYS_TERMINATION               Correlation: 0.016981	Status: very weak
# Title: DAYS_LAST_DUE                  Correlation: 0.017522	Status: very weak
# Title: DAYS_LAST_DUE_1ST_VERSION      Correlation: 0.018021	Status: very weak
# Title: NAME_CASH_LOAN_PURPOSE_Repairs Correlation: 0.018582	Status: very weak
# Title: PRODUCT_COMBINATION_Cash_Street:_high Correlation: 0.018768	Status: very weak
# Title: PRODUCT_COMBINATION_Cash_X-Sell:_high Correlation: 0.019489	Status: very weak
# Title: NAME_PORTFOLIO_XNA             Correlation: 0.020415	Status: very weak
# Title: NAME_CONTRACT_TYPE_Revolving_loans Correlation: 0.023149	Status: very weak
# Title: PRODUCT_COMBINATION_Card_Street Correlation: 0.025096	Status: very weak
# Title: NAME_SELLER_INDUSTRY_XNA       Correlation: 0.025203	Status: very weak
# Title: CODE_REJECT_REASON_LIMIT       Correlation: 0.025967	Status: very weak
# Title: NAME_PAYMENT_TYPE_XNA          Correlation: 0.026353	Status: very weak
# Title: CHANNEL_TYPE_AP+_(Cash_loan)   Correlation: 0.028294	Status: very weak
# Title: NAME_YIELD_GROUP_XNA           Correlation: 0.028366	Status: very weak
# Title: RATE_INTEREST_PRIVILEGED       Correlation: 0.02864	Status: very weak
# Title: NAME_GOODS_CATEGORY_XNA        Correlation: 0.029541	Status: very weak
# Title: CNT_PAYMENT                    Correlation: 0.03048	Status: very weak
# Title: CODE_REJECT_REASON_HC          Correlation: 0.037158	Status: very weak
# Title: CODE_REJECT_REASON_SCOFR       Correlation: 0.038432	Status: very weak
# Title: DAYS_DECISION                  Correlation: 0.039901	Status: very weak
# Title: NAME_PRODUCT_TYPE_walk-in      Correlation: 0.042842	Status: very weak
# Title: NAME_CONTRACT_STATUS_Refused   Correlation: 0.054458	Status: very weak
# Title: TARGET                         Correlation:   1.0	Status: very strong

# %%
#CELL 12
#Check number of columns after pre-processing
len(csv_df.columns)
# Out:
# 254

# %%
#CELL 13
#Columns from Previous_Application to use:

#Postive Correlations
#Title: CODE_REJECT_REASON_XAP         Correlation: 0.052015	Status: very weak                                         
#Title: NAME_CONTRACT_STATUS_Approved  Correlation: 0.049161	Status: very weak                                         
#Title: DAYS_FIRST_DRAWING             Correlation: 0.031154	Status: very weak                                         
#Title: NAME_PORTFOLIO_POS             Correlation: 0.030791	Status: very weak  

#Negative Correlations:
#Title: CODE_REJECT_REASON_HC          Correlation: 0.037158	Status: very weak                                         
#Title: CODE_REJECT_REASON_SCOFR       Correlation: 0.038432	Status: very weak                                         
#Title: DAYS_DECISION                  Correlation: 0.039901	Status: very weak                                         
#Title: NAME_PRODUCT_TYPE_walk-in      Correlation: 0.042842	Status: very weak                                         
#Title: NAME_CONTRACT_STATUS_Refused   Correlation: 0.054458	Status: very weak  

#'CODE_REJECT_REASON'

# %%
#CELL 14
#NOTE BOOK PART TWO:
#Read in application train, add in column from previous application, perform pre-processing then check if ROC_AUC Curve improves.
del correlations, csv_df

# %%
#CELL 15
#Re-run cells 1-4 to read in both application_train and previous_app (REMEMBER NOT TO CALL THE GARBAGE COLLECTOR ON application_train this time since we still need it)
#Merge or inner join the additional columns from filtered Apps and train_df together 
additional_Columns=filteredApps[['SK_ID_CURR','NAME_CONTRACT_STATUS','CODE_REJECT_REASON']]
csv_df=train_df.merge(additional_Columns,on='SK_ID_CURR',how='inner')

#No longer need filteredApps and train_df
del filteredApps,train_df
gc.collect()

#Re-run cells 7,8,9 & 12 (label-encoding and pre-processing (also length of columns check if desired),
#then run the rest of the cell, (this takes a while)
#See if ROC_AUC curve has improved, keept track of findings, repeat
# Out:
# 52

# %%
#CELL 16
#Lets run our classifier to check the ROC_AUC curve before adding in any extra columns. 
#Split csvfile into train and test. 
X_train, X_valid, y_train, y_valid = train_test_split(
    csv_df.drop(['TARGET','SK_ID_CURR'], axis=1), csv_df['TARGET'],
    test_size=0.3, random_state=17)

# %%
#CELL 17
#Run lightGBM 
lgb_clf=LGBMClassifier(random_state=17)
lgb_clf.fit(X_train,y_train)

#Avoid memory errors
#del lgb_clf
#gc.collect()
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=17, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
#CELL 18
#Calculate ROC AUC Score 
yvalid_preds= lgb_clf.predict(X_valid)
print ('ROC AUC Score on the test dataset', roc_auc_score (y_valid, yvalid_preds))
# Out:
# ROC AUC Score on the test dataset 0.5160818458998756

# %%
#CELL 19
#TO DO: Determine threshold

#yvalid_preds = lgb_clf.predict_proba(X_valid)[:, 1]
#yvalid_preds_threshold = [1 if pred > 0.10 else 0 for pred in yvalid_preds]
#yvalid_preds= lgb_clf.predict(X_valid)

# %%
#CELL 20
#Visualize the ROC AUC Curve 
#Reference: https://www.kaggle.com/jomaxx/area-under-the-roc-curve-explained 

#calculate false positive rate and true positive rate for all thresholds of the classification
fpr,tpr, thresholds= roc_curve(y_valid, yvalid_preds) 
roc_auc=auc(fpr,tpr)

#Plot ROC 
plt.plot(fpr, tpr, lw=1, label='(AUC = %0.2f)' % (roc_auc))

plt.title('LGB Classifier Receiver Operating Characteristic ')
plt.legend(loc="lower right")
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

# %%
#CELL 21 
#Code to write to a file and save it in the S3: bucket 
#from io import StringIO # python3; python2: BytesIO 
#import boto3

#bucket = "data-science-group12"
#fileName = "test.csv"

#csv_buffer = StringIO()
#test_df.to_csv(csv_buffer)
#s3_resource = boto3.resource('s3')
#s3_resource.Object(bucket, fileName).put(Body=csv_buffer.getvalue())

# %%
#CELL 22
#Previous: ROC AUC Score on the test dataset 0.5000517792764566
#ROC AUC Score on the test dataset 0.5164656366487126
#ROC AUC Score on the test dataset 0.5160818458998756

# %%
#CELL 23
#NOTEBOOK PART 3 : LEARNING GROUP BY ON PREVIOUS APPLICATION

# %%
#CELL 24
del train_df 
gc.collect()

csv_df=filteredApps

# %%
#CELL 25
groups=csv_df.groupby('SK_ID_CURR')
groups.first()
# Out:
#             SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# SK_ID_CURR
# 100002         1038818     Consumer loans     9251.775       179055.000
# 100003         1810518         Cash loans    98356.995       900000.000
# 100004         1564014     Consumer loans     5357.250        24282.000
# 100006         2827850    Revolving loans     2482.920            0.000
# 100007         2001242         Cash loans    16509.600       180000.000
# 100008         1757431         Cash loans    12144.285            0.000
# 100009         2421381     Consumer loans     7435.845        47160.000
# 100010         2349489     Consumer loans    27463.410       247212.000
# 100011         1430602     Consumer loans    14614.335       135931.500
# 100012         2164190         Cash loans    11188.035       135000.000
# 100014         1461079     Consumer loans    11567.475       119272.500
# 100015         1027737     Consumer loans     7666.920        68850.000
# 100016         1515914     Consumer loans     6042.915        47115.000
# 100017         2769249     Consumer loans    16967.295       158040.000
# 100018         2704445     Consumer loans    94906.035       536364.000
# 100019         1620327     Consumer loans    10518.615        84136.500
# 100020         1074770     Consumer loans     5729.265        32512.500
# 100021         2425547     Consumer loans    10248.615        99189.000
# 100022         1319299     Consumer loans     6765.975        89091.000
# 100023         2454202         Cash loans    16822.440       180000.000
# 100025         2023031     Consumer loans    17682.975        95625.000
# 100026         1701107         Cash loans    23608.485            0.000
# 100027         2447872     Consumer loans    28077.570       226984.500
# 100029         2662898     Consumer loans    22891.680       126000.000
# 100030         1354305     Consumer loans     6014.835        33561.000
# 100032         1514328     Consumer loans     7910.145        69255.000
# 100033         2037234     Consumer loans     5542.920        53599.500
# 100034         1187878     Consumer loans    21281.130       121455.000
# 100035         2019479         Cash loans    12001.860            0.000
# 100036         2430929         Cash loans    13290.300            0.000
# ...                ...                ...          ...              ...
# 456220         2571989     Consumer loans     5618.790        38911.500
# 456225         2540846         Cash loans    31446.360       450000.000
# 456226         1176398         Cash loans    60461.055       540000.000
# 456227         1478886         Cash loans    11813.580            0.000
# 456228         2200052     Consumer loans    16776.990       143640.000
# 456230         1065285     Consumer loans    32594.175       274086.990
# 456231         1804479         Cash loans    17751.420       450000.000
# 456232         2497468     Consumer loans    11999.295       199755.000
# 456233         2458558    Revolving loans     2250.000        45000.000
# 456234         2414642     Consumer loans     4954.140        29655.000
# 456235         1499583    Revolving loans     2250.000        45000.000
# 456236         1138749         Cash loans    19607.445       135000.000
# 456237         2002253         Cash loans    20123.865       225000.000
# 456238         2793441     Consumer loans     9638.730       119375.325
# 456239         1979295     Consumer loans     4797.450        18112.500
# 456240         1261348         Cash loans    30375.270       472500.000
# 456241         1367270     Consumer loans    12697.200       136845.000
# 456242         2640681    Revolving loans     2250.000        45000.000
# 456243         1892799         Cash loans     9476.955        90000.000
# 456244         1165146         Cash loans    44312.535       900000.000
# 456245         1666363         Cash loans     6481.755        90000.000
# 456246         1129524     Consumer loans     6747.660        36031.500
# 456247         2797706     Consumer loans     5250.645        47781.000
# 456248         2743495    Revolving loans    45000.000            0.000
# 456249         2660508         Cash loans    22770.405       180000.000
# 456251         2248017     Consumer loans     6605.910        40455.000
# 456252         1503599     Consumer loans    10074.465        57595.500
# 456253         1686207     Consumer loans     5567.715        28912.500
# 456254         1792910     Consumer loans     2296.440        18846.000
# 456255         1708056    Revolving loans     2250.000        45000.000
#
#             AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# SK_ID_CURR
# 100002        179055.0             0.000       179055.000
# 100003       1035882.0             0.000       900000.000
# 100004         20106.0          4860.000        24282.000
# 100006             0.0          2693.340        26912.340
# 100007        180000.0          3105.000       180000.000
# 100008             0.0         12145.500       121455.000
# 100009         39721.5          9432.000        47160.000
# 100010        260811.0             0.000       247212.000
# 100011        134446.5         13594.500       135931.500
# 100012        158508.0             0.000       135000.000
# 100014        131868.0             0.000       119272.500
# 100015         67077.0          6885.000        68850.000
# 100016         51781.5             0.000        47115.000
# 100017        152721.0         15804.000       158040.000
# 100018        536364.0             0.000       536364.000
# 100019        104683.5             0.000        84136.500
# 100020         35086.5             0.000        32512.500
# 100021         98694.0          9922.500        99189.000
# 100022        103203.0             0.000        89091.000
# 100023        239242.5          7870.500       180000.000
# 100025         95625.0             0.000        95625.000
# 100026             0.0             0.000       132345.000
# 100027        239467.5             0.000       226984.500
# 100029        126000.0             0.000       126000.000
# 100030         27954.0          6714.000        33561.000
# 100032         42255.0         27000.000        69255.000
# 100033         53329.5          5364.000        53599.500
# 100034        115083.0         12145.500       121455.000
# 100035             0.0          9360.000       117000.000
# 100036             0.0             0.000       197752.500
# ...                ...               ...              ...
# 456220         42120.0             0.000        38911.500
# 456225        491580.0               NaN       450000.000
# 456226        561384.0               NaN       540000.000
# 456227             0.0             0.000       112500.000
# 456228        140652.0         14364.000       143640.000
# 456230        292176.0             0.990       274086.990
# 456231        533160.0             0.000       450000.000
# 456232        199755.0             0.000       199755.000
# 456233         45000.0             0.000        45000.000
# 456234         24489.0          9000.000        29655.000
# 456235         45000.0         14085.000        45000.000
# 456236        165226.5             0.000       135000.000
# 456237        254700.0               NaN       225000.000
# 456238         95499.0         23876.325       119375.325
# 456239         16839.0          1813.500        18112.500
# 456240        528633.0             0.000       472500.000
# 456241        125667.0         22500.000       136845.000
# 456242         45000.0             0.000        45000.000
# 456243         95940.0         18000.000        90000.000
# 456244       1042767.0             0.000       900000.000
# 456245        116077.5               NaN        90000.000
# 456246         33093.0          4500.000        36031.500
# 456247         47781.0             0.000        47781.000
# 456248        900000.0             0.000      1260000.000
# 456249        191880.0             0.000       180000.000
# 456251         40455.0             0.000        40455.000
# 456252         56821.5          3456.000        57595.500
# 456253         27306.0          2893.500        28912.500
# 456254         21456.0             0.000        18846.000
# 456255         45000.0          9000.000        45000.000
#
#            WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                       SATURDAY                        9
# 100003                         FRIDAY                       12
# 100004                         FRIDAY                        5
# 100006                       THURSDAY                       15
# 100007                         SUNDAY                       14
# 100008                         FRIDAY                       18
# 100009                         SUNDAY                       11
# 100010                        TUESDAY                       16
# 100011                         MONDAY                       17
# 100012                         FRIDAY                       13
# 100014                        TUESDAY                       13
# 100015                      WEDNESDAY                        8
# 100016                         MONDAY                       12
# 100017                      WEDNESDAY                       15
# 100018                       SATURDAY                       14
# 100019                         FRIDAY                       10
# 100020                       SATURDAY                       10
# 100021                         FRIDAY                       19
# 100022                       THURSDAY                       18
# 100023                         FRIDAY                        9
# 100025                         MONDAY                       17
# 100026                       SATURDAY                        6
# 100027                         MONDAY                       16
# 100029                       SATURDAY                       18
# 100030                         SUNDAY                       15
# 100032                         SUNDAY                       10
# 100033                         MONDAY                       14
# 100034                         MONDAY                       19
# 100035                       THURSDAY                       11
# 100036                      WEDNESDAY                        9
# ...                               ...                      ...
# 456220                        TUESDAY                       12
# 456225                        TUESDAY                       16
# 456226                        TUESDAY                       13
# 456227                         FRIDAY                       13
# 456228                         FRIDAY                       17
# 456230                         SUNDAY                       16
# 456231                        TUESDAY                       15
# 456232                        TUESDAY                       18
# 456233                       SATURDAY                       10
# 456234                         MONDAY                       18
# 456235                       THURSDAY                       11
# 456236                      WEDNESDAY                        8
# 456237                       THURSDAY                       11
# 456238                       SATURDAY                       19
# 456239                       THURSDAY                       11
# 456240                       THURSDAY                        9
# 456241                       SATURDAY                       18
# 456242                         MONDAY                       15
# 456243                         FRIDAY                       16
# 456244                         FRIDAY                        8
# 456245                         FRIDAY                       10
# 456246                       THURSDAY                       15
# 456247                         SUNDAY                       13
# 456248                         FRIDAY                       16
# 456249                         MONDAY                        8
# 456251                       THURSDAY                       17
# 456252                      WEDNESDAY                       10
# 456253                       SATURDAY                       12
# 456254                      WEDNESDAY                       12
# 456255                         SUNDAY                       14
#
#            FLAG_LAST_APPL_PER_CONTRACT            ...             \
# SK_ID_CURR                                        ...
# 100002                               Y            ...
# 100003                               Y            ...
# 100004                               Y            ...
# 100006                               Y            ...
# 100007                               Y            ...
# 100008                               Y            ...
# 100009                               Y            ...
# 100010                               Y            ...
# 100011                               Y            ...
# 100012                               Y            ...
# 100014                               Y            ...
# 100015                               Y            ...
# 100016                               Y            ...
# 100017                               Y            ...
# 100018                               Y            ...
# 100019                               Y            ...
# 100020                               Y            ...
# 100021                               Y            ...
# 100022                               Y            ...
# 100023                               Y            ...
# 100025                               Y            ...
# 100026                               Y            ...
# 100027                               Y            ...
# 100029                               Y            ...
# 100030                               Y            ...
# 100032                               Y            ...
# 100033                               Y            ...
# 100034                               Y            ...
# 100035                               Y            ...
# 100036                               Y            ...
# ...                                ...            ...
# 456220                               Y            ...
# 456225                               Y            ...
# 456226                               Y            ...
# 456227                               Y            ...
# 456228                               Y            ...
# 456230                               Y            ...
# 456231                               Y            ...
# 456232                               Y            ...
# 456233                               Y            ...
# 456234                               Y            ...
# 456235                               Y            ...
# 456236                               Y            ...
# 456237                               Y            ...
# 456238                               Y            ...
# 456239                               Y            ...
# 456240                               Y            ...
# 456241                               Y            ...
# 456242                               Y            ...
# 456243                               Y            ...
# 456244                               Y            ...
# 456245                               Y            ...
# 456246                               Y            ...
# 456247                               Y            ...
# 456248                               Y            ...
# 456249                               Y            ...
# 456251                               Y            ...
# 456252                               Y            ...
# 456253                               Y            ...
# 456254                               Y            ...
# 456255                               Y            ...
#
#             NAME_SELLER_INDUSTRY  CNT_PAYMENT  NAME_YIELD_GROUP  \
# SK_ID_CURR
# 100002           Auto technology         24.0        low_normal
# 100003                       XNA         12.0        low_normal
# 100004              Connectivity          4.0            middle
# 100006                       XNA         12.0               XNA
# 100007      Consumer electronics         18.0              high
# 100008                       XNA         10.0               XNA
# 100009      Consumer electronics          6.0            middle
# 100010                 Furniture         10.0        low_action
# 100011      Consumer electronics         12.0              high
# 100012                       XNA         24.0              high
# 100014      Consumer electronics         12.0        low_action
# 100015                 Furniture         10.0            middle
# 100016      Consumer electronics         12.0              high
# 100017                 Furniture         10.0        low_normal
# 100018              Construction          6.0        low_normal
# 100019      Consumer electronics         12.0            middle
# 100020      Consumer electronics          8.0              high
# 100021      Consumer electronics         12.0            middle
# 100022      Consumer electronics         18.0        low_normal
# 100023                       XNA         24.0              high
# 100025                 Furniture          6.0            middle
# 100026                       XNA          6.0               XNA
# 100027      Consumer electronics         10.0            middle
# 100029                  Clothing          6.0            middle
# 100030              Connectivity          5.0        low_normal
# 100032      Consumer electronics          6.0            middle
# 100033              Connectivity         12.0            middle
# 100034      Consumer electronics          6.0            middle
# 100035                       XNA         12.0               XNA
# 100036                       XNA         18.0               XNA
# ...                          ...          ...               ...
# 456220              Connectivity         10.0              high
# 456225                       XNA         24.0            middle
# 456226                       XNA         12.0            middle
# 456227                       XNA         12.0               XNA
# 456228      Consumer electronics         10.0            middle
# 456230      Consumer electronics         10.0        low_normal
# 456231                       XNA         48.0        low_normal
# 456232                 Furniture         18.0        low_action
# 456233      Consumer electronics          0.0               XNA
# 456234              Connectivity          6.0              high
# 456235              Construction          0.0               XNA
# 456236                       XNA         12.0              high
# 456237              Connectivity         24.0              high
# 456238              Connectivity         12.0            middle
# 456239              Connectivity          4.0        low_normal
# 456240                       XNA         36.0              high
# 456241      Consumer electronics         12.0            middle
# 456242      Consumer electronics          0.0               XNA
# 456243      Consumer electronics         12.0        low_normal
# 456244                       XNA         36.0        low_normal
# 456245                       XNA         24.0        low_normal
# 456246              Connectivity          6.0              high
# 456247              Connectivity         10.0        low_normal
# 456248                       XNA          0.0               XNA
# 456249                       XNA         12.0              high
# 456251              Connectivity          8.0              high
# 456252      Consumer electronics          6.0        low_normal
# 456253              Connectivity          6.0              high
# 456254              Connectivity         14.0              high
# 456255              Connectivity          0.0               XNA
#
#                        PRODUCT_COMBINATION DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# SK_ID_CURR
# 100002             POS other with interest           365243.0         -565.0
# 100003                    Cash X-Sell: low           365243.0         -716.0
# 100004         POS mobile without interest           365243.0         -784.0
# 100006                         Card Street           365243.0         -545.0
# 100007                   Cash Street: high           365243.0         -834.0
# 100008                                Cash           365243.0        -2299.0
# 100009         POS household with interest           365243.0         -795.0
# 100010       POS industry without interest           365243.0        -1039.0
# 100011         POS household with interest           365243.0        -2477.0
# 100012                   Cash X-Sell: high           365243.0         -802.0
# 100014      POS household without interest           365243.0         -813.0
# 100015          POS industry with interest           365243.0        -2360.0
# 100016         POS household with interest           365243.0        -2339.0
# 100017       POS industry without interest           365243.0        -2398.0
# 100018          POS industry with interest           365243.0         -955.0
# 100019         POS household with interest           365243.0         -894.0
# 100020         POS household with interest           365243.0         -211.0
# 100021         POS household with interest           365243.0         -819.0
# 100022         POS household with interest           365243.0         -209.0
# 100023                   Cash X-Sell: high           365243.0         -232.0
# 100025             POS other with interest           365243.0       365243.0
# 100026                                Cash           365243.0        -1396.0
# 100027         POS household with interest           365243.0         -764.0
# 100029          POS industry with interest           365243.0         -293.0
# 100030         POS mobile without interest           365243.0         -347.0
# 100032         POS household with interest           365243.0        -1466.0
# 100033            POS mobile with interest           365243.0         -818.0
# 100034         POS household with interest           365243.0         -257.0
# 100035                                Cash           365243.0        -1728.0
# 100036                                Cash           365243.0       365243.0
# ...                                    ...                ...            ...
# 456220            POS mobile with interest           365243.0        -2282.0
# 456225                 Cash X-Sell: middle           365243.0        -1066.0
# 456226                 Cash Street: middle           365243.0         -578.0
# 456227                                Cash           365243.0         -642.0
# 456228         POS household with interest           365243.0         -785.0
# 456230      POS household without interest           365243.0          -46.0
# 456231                    Cash X-Sell: low           365243.0         -816.0
# 456232       POS industry without interest           365243.0         -577.0
# 456233                         Card Street             -241.0         -204.0
# 456234            POS mobile with interest           365243.0         -968.0
# 456235                         Card Street           365243.0       365243.0
# 456236                   Cash Street: high           365243.0        -1544.0
# 456237                   Cash Street: high           365243.0         -845.0
# 456238            POS mobile with interest           365243.0         -324.0
# 456239            POS mobile with interest           365243.0        -2888.0
# 456240                   Cash X-Sell: high           365243.0         -425.0
# 456241         POS household with interest           365243.0        -1044.0
# 456242                         Card Street             -231.0         -198.0
# 456243                    Cash X-Sell: low           365243.0        -1575.0
# 456244                    Cash X-Sell: low           365243.0        -1552.0
# 456245                    Cash X-Sell: low           365243.0         -192.0
# 456246            POS mobile with interest           365243.0        -1480.0
# 456247         POS mobile without interest           365243.0         -616.0
# 456248                         Card X-Sell           365243.0       365243.0
# 456249                   Cash Street: high           365243.0        -1495.0
# 456251            POS mobile with interest           365243.0         -210.0
# 456252      POS household without interest           365243.0        -2466.0
# 456253            POS mobile with interest           365243.0        -1866.0
# 456254            POS mobile with interest           365243.0         -291.0
# 456255                         Card Street           365243.0         -425.0
#
#             DAYS_LAST_DUE_1ST_VERSION DAYS_LAST_DUE DAYS_TERMINATION  \
# SK_ID_CURR
# 100002                          125.0         -25.0            -17.0
# 100003                         -386.0        -536.0           -527.0
# 100004                         -694.0        -724.0           -714.0
# 100006                         -215.0        -425.0           -416.0
# 100007                         -324.0        -354.0           -347.0
# 100008                        -2029.0       -2029.0           -703.0
# 100009                         -645.0        -645.0           -636.0
# 100010                         -769.0        -769.0           -762.0
# 100011                        -2147.0       -2147.0          -1186.0
# 100012                         -112.0        -142.0           -137.0
# 100014                         -483.0        -483.0           -475.0
# 100015                        -2090.0       -2090.0          -2084.0
# 100016                        -2009.0       -2009.0          -2007.0
# 100017                        -2128.0       -2128.0          -2122.0
# 100018                         -805.0        -787.0           -784.0
# 100019                         -564.0        -714.0           -705.0
# 100020                           -1.0      365243.0         365243.0
# 100021                         -489.0        -669.0           -657.0
# 100022                          301.0      365243.0         365243.0
# 100023                          458.0        -142.0           -134.0
# 100025                          176.0      365243.0         365243.0
# 100026                        -1246.0       -1246.0          -1243.0
# 100027                         -494.0        -494.0           -488.0
# 100029                         -143.0        -203.0           -197.0
# 100030                         -197.0        -227.0           -223.0
# 100032                        -1316.0       -1316.0          -1300.0
# 100033                         -488.0        -488.0           -486.0
# 100034                         -107.0        -167.0           -163.0
# 100035                        -1398.0       -1398.0          -1396.0
# 100036                       365243.0      365243.0         365243.0
# ...                               ...           ...              ...
# 456220                        -2012.0       -2012.0          -2007.0
# 456225                          -16.0         -16.0            -12.0
# 456226                         -248.0        -488.0           -480.0
# 456227                         -312.0        -432.0           -414.0
# 456228                         -515.0        -515.0           -512.0
# 456230                          224.0      365243.0         365243.0
# 456231                         -666.0        -666.0           -660.0
# 456232                          -67.0         -67.0            -59.0
# 456233                       365243.0      365243.0         365243.0
# 456234                         -818.0        -848.0           -839.0
# 456235                       365243.0      365243.0         365243.0
# 456236                         -854.0       -1304.0          -1300.0
# 456237                         -131.0        -845.0           -841.0
# 456238                            6.0        -234.0           -226.0
# 456239                        -2798.0       -2798.0          -2608.0
# 456240                          625.0      365243.0         365243.0
# 456241                         -714.0        -714.0           -710.0
# 456242                       365243.0      365243.0         365243.0
# 456243                        -1305.0       -1335.0          -1332.0
# 456244                         -862.0       -1372.0          -1363.0
# 456245                          498.0      365243.0         365243.0
# 456246                        -1330.0       -1330.0          -1324.0
# 456247                         -346.0        -586.0           -580.0
# 456248                       365243.0      365243.0         365243.0
# 456249                        -1165.0       -1165.0          -1156.0
# 456251                            0.0         -30.0            -25.0
# 456252                        -2316.0       -2316.0          -2311.0
# 456253                        -1716.0       -1716.0          -1712.0
# 456254                           99.0      365243.0         365243.0
# 456255                          -95.0        -215.0           -211.0
#
#            NFLAG_INSURED_ON_APPROVAL
# SK_ID_CURR
# 100002                           0.0
# 100003                           1.0
# 100004                           0.0
# 100006                           0.0
# 100007                           0.0
# 100008                           0.0
# 100009                           0.0
# 100010                           0.0
# 100011                           1.0
# 100012                           1.0
# 100014                           0.0
# 100015                           1.0
# 100016                           1.0
# 100017                           1.0
# 100018                           0.0
# 100019                           0.0
# 100020                           0.0
# 100021                           0.0
# 100022                           1.0
# 100023                           1.0
# 100025                           0.0
# 100026                           0.0
# 100027                           0.0
# 100029                           0.0
# 100030                           0.0
# 100032                           0.0
# 100033                           0.0
# 100034                           0.0
# 100035                           0.0
# 100036                           0.0
# ...                              ...
# 456220                           1.0
# 456225                           1.0
# 456226                           0.0
# 456227                           1.0
# 456228                           0.0
# 456230                           1.0
# 456231                           1.0
# 456232                           0.0
# 456233                           0.0
# 456234                           0.0
# 456235                           0.0
# 456236                           1.0
# 456237                           1.0
# 456238                           0.0
# 456239                           1.0
# 456240                           1.0
# 456241                           0.0
# 456242                           0.0
# 456243                           0.0
# 456244                           1.0
# 456245                           1.0
# 456246                           0.0
# 456247                           0.0
# 456248                           0.0
# 456249                           0.0
# 456251                           0.0
# 456252                           1.0
# 456253                           0.0
# 456254                           0.0
# 456255                           0.0
#
# [291057 rows x 36 columns]

# %%
#CELL 26
groups.get_group(456253)['PRODUCT_COMBINATION']
# Out:
# 181558     POS mobile with interest
# 1246881    POS mobile with interest
# Name: PRODUCT_COMBINATION, dtype: object

# %%
#CELL 27
groups.get_group(456255)
# Out:
#          AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  \
# 729432      2250.000          45000.0     45000.0               NaN
# 453227     11314.170          82404.0     93298.5            9000.0
# 608510     16400.610         229500.0    254340.0               NaN
# 214743     11090.835         102037.5    112815.0               0.0
# 1411592    11514.555          58225.5     58545.0            5823.0
# 596623     28873.170         450000.0    491580.0               NaN
# 814647     30737.655         765000.0   1067940.0               NaN
# 1383554    54022.140        1170000.0   1271929.5               NaN
#
#          AMT_GOODS_PRICE             CHANNEL_TYPE  CNT_PAYMENT  \
# 729432           45000.0             Country-wide          0.0
# 453227           82404.0             Country-wide         12.0
# 608510          229500.0  Credit and cash offices         24.0
# 214743          102037.5         Regional / Local         12.0
# 1411592          58225.5             Country-wide          6.0
# 596623          450000.0  Credit and cash offices         24.0
# 814647          765000.0  Credit and cash offices         60.0
# 1383554        1170000.0          AP+ (Cash loan)         36.0
#
#         CODE_REJECT_REASON  DAYS_DECISION  DAYS_FIRST_DRAWING  \
# 729432                  HC           -456                 NaN
# 453227                 XAP           -456            365243.0
# 608510                 XAP           -648            365243.0
# 214743                 XAP           -991            365243.0
# 1411592                XAP           -500            365243.0
# 596623                 XAP           -692            365243.0
# 814647                  HC           -171                 NaN
# 1383554                XAP           -787            365243.0
#
#                    ...              NAME_YIELD_GROUP  \
# 729432             ...                           XNA
# 453227             ...                          high
# 608510             ...                        middle
# 214743             ...                        middle
# 1411592            ...                          high
# 596623             ...                        middle
# 814647             ...                    low_normal
# 1383554            ...                    low_normal
#
#          NFLAG_INSURED_ON_APPROVAL  NFLAG_LAST_APPL_IN_DAY  \
# 729432                         NaN                       1
# 453227                         0.0                       1
# 608510                         1.0                       1
# 214743                         0.0                       1
# 1411592                        0.0                       1
# 596623                         1.0                       1
# 814647                         NaN                       1
# 1383554                        0.0                       1
#
#                 PRODUCT_COMBINATION RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  \
# 729432                  Card Street               NaN                    NaN
# 453227     POS mobile with interest          0.095816                    NaN
# 608510          Cash X-Sell: middle               NaN                    NaN
# 214743   POS industry with interest          0.000000                    NaN
# 1411592    POS mobile with interest          0.098524                    NaN
# 596623          Cash X-Sell: middle               NaN                    NaN
# 814647             Cash Street: low               NaN                    NaN
# 1383554            Cash X-Sell: low               NaN                    NaN
#
#         RATE_INTEREST_PRIVILEGED SELLERPLACE_AREA SK_ID_PREV  \
# 729432                       NaN               20    1708056
# 453227                       NaN               50    1359084
# 608510                       NaN               -1    2073384
# 214743                       NaN              500    1743609
# 1411592                      NaN               20    2729207
# 596623                       NaN               -1    1179690
# 814647                       NaN               -1    1296007
# 1383554                      NaN                6    2631384
#
#         WEEKDAY_APPR_PROCESS_START
# 729432                      SUNDAY
# 453227                      SUNDAY
# 608510                    THURSDAY
# 214743                    THURSDAY
# 1411592                     FRIDAY
# 596623                     TUESDAY
# 814647                      FRIDAY
# 1383554                     FRIDAY
#
# [8 rows x 36 columns]

# %%
#CELL 28
